# %% [markdown]
# # Paper Reimplementation Walkthrough
# This notebook runs the bundled smoke pipeline and then points to paper-mode execution.

# %%
# !python ../scripts/reproduce_all.py --config ../configs/smoke.yaml

# %%
import json
print(json.load(open('../outputs/metrics.json')))

# %% [markdown]
# For a TDD run, acquire the dataset first and use `configs/paper.yaml`.
